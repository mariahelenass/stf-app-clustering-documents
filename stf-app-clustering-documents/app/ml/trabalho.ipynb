# %% [markdown]
# ## STF Document Clustering using VICTOR Dataset
# https://aclanthology.org/2020.lrec-1.181.pdf

# %% [markdown]
# Premissas do artigo
# - To ensure the reproducibility of our experiments we ran
# domly divided the appeals into 70%/15%/15% splits for
# train/validation/test respectively, maintaining theme distri
# bution across them.

# %%
import pandas as pd
import plotly.express as px
import json
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df_doc = pd.read_csv('train_medium.csv')

# %%
df_doc.columns
# Out:
# Index(['themes', 'process_id', 'file_name', 'document_type', 'pages', 'body'], dtype='object')

# %%
df_doc.head()
# Out:
#   themes process_id                              file_name document_type  \
# 0  [225]  AI_635072  AI_635072_15320124014_80_13032015.pdf        outros
# 1  [225]  AI_635072  AI_635072_15320124014_80_13032015.pdf        outros
# 2  [225]  AI_635072  AI_635072_288462549_1060_13032015.pdf        outros
# 3  [225]  AI_635072  AI_635072_289561047_1280_15122014.pdf        outros
# 4  [225]  AI_635072  AI_635072_306972753_1280_02062015.pdf        outros
#
#    pages                                               body
# 0      1  {"çft manê ado intimação extraído relação das ...
# 1      2  {"certidão certifico que dirigi nesta capital ...
# 2      1  {"supremo tribunal federal agravo instrumento ...
# 3      1  {"supremo tribunal federal certidão agravo ins...
# 4      1  {"supremo tribunal federal ofício brasília de ...

# %%
df_view = df_doc.drop_duplicates(subset=["process_id", "file_name"])

# %%
doc_counts = df_view["document_type"].value_counts().reset_index()
doc_counts.columns = ["document_type", "count"]

fig = px.bar(
    doc_counts,
    x="document_type",
    y="count",
    title="Quantidade de documentos por tipo",
    text="count",
    color="document_type"
)

fig.update_layout(
    width=900,  
    height=600,  
)
fig.show()

# %% [markdown]
# Dados desbalanceados
# - Muito dado pertence a classe outros
# - Buscar formas de lidar com esses dados desbalanceados

# %%
df_view.head()
# Out:
#   themes process_id                              file_name document_type  \
# 0  [225]  AI_635072  AI_635072_15320124014_80_13032015.pdf        outros
# 2  [225]  AI_635072  AI_635072_288462549_1060_13032015.pdf        outros
# 3  [225]  AI_635072  AI_635072_289561047_1280_15122014.pdf        outros
# 4  [225]  AI_635072  AI_635072_306972753_1280_02062015.pdf        outros
# 5  [225]  AI_635072  AI_635072_306981455_1280_03062015.pdf        outros
#
#    pages                                               body
# 0      1  {"çft manê ado intimação extraído relação das ...
# 2      1  {"supremo tribunal federal agravo instrumento ...
# 3      1  {"supremo tribunal federal certidão agravo ins...
# 4      1  {"supremo tribunal federal ofício brasília de ...
# 5      1  {"supremo tribunal federal ofício brasília de ...

# %%
themes_counts = df_view["themes"].value_counts().reset_index()
themes_counts.columns = ["theme", "count"]

fig = px.bar(
    themes_counts.head(10),  
    x="theme",
    y="count",
    text="count",
    title="Temas mais frequentes na base VICTOR",
    color="theme"
)

fig.update_traces(textposition='outside')
fig.update_layout(xaxis_title="Tema", yaxis_title="Quantidade de documentos")

fig.show()

# %% [markdown]
# Tema 695: Inclusão do décimo terceiro salário no cálculo do salário-benefício para apuração da Renda Mensal Inicial (RMI)
#
# Tema 692: Possibilidade de o CONFEA fixar valores de taxas por resolução
#
# Tema 800: Presunção relativa de inexistência de repercussão geral de recursos extraordinários nos Juizados Especiais Cíveis (Lei 9.099/1995)
#
# Tema 503: Apenas lei pode criar benefícios e vantagens previdenciárias no RGPS
#
# Tema 163: Contribuição previdenciária sobre férias, gratificação natalina, horas extras, adicional noturno etc.
#
# Tema 540: Fixação de anuidade por conselhos de fiscalização profissional é inconstitucional quando delegada por lei

# %%
df_outros = df_view[df_view['document_type'] == 'outros']

themes_outros = df_outros["themes"].value_counts().reset_index()
themes_outros.columns = ["theme", "count"]


fig = px.bar(
    themes_outros.head(10),  
    x="theme",
    y="count",
    text="count",
    title="Temas mais frequentes na base VICTOR no tipo de documentos 'outros'",
    color="theme"
)

fig.update_traces(textposition='outside')
fig.update_layout(
    xaxis_title="Tema", 
    yaxis_title="Quantidade de documentos"
)

fig.show()

# %%
from nltk.tokenize import word_tokenize
import nltk
import string
import spacy
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import unicodedata

# %% [markdown]
# ### Tratamento de dados

# %%
# removendo a classe desbalanceada 
doc = df_doc[df_doc['document_type'] != "outros"]

# %%
doc.head()
# Out:
#    themes process_id                        file_name           document_type  \
# 71   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
# 72   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
# 73   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
# 74   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
# 75   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
#
#     pages                                               body
# 71      1  {"poder judiciário estado acre gabinete desemb...
# 72      2  {"poder judiciário estado acre gabinete desemb...
# 73      3  {"poder judiciário estado acre gabinete desemb...
# 74      4  {"poder judiciário estado acre gabinete desemb...
# 75      5  {"c f d poder judiciário estado acre gabinete ...

# %%
# "stopwords" brasileiras
with open("stopwords_br.txt", "r", encoding="utf-8") as f:
    stop_words = set([x.strip().lower() for x in f.readlines()])

# %%
# "stopwords" jurídicas
with open("stopwords_juridicas.txt", "r", encoding="utf-8") as f:
    juridicas = set([x.strip().lower() for x in f.readlines()])

# %%
# estados brasileiros e topicos comuns
with open("topicos_comuns.txt", "r", encoding="utf-8") as f:
    topicos_comuns = set([x.strip().lower() for x in f.readlines()])

# %%
stop_words = stop_words.union(juridicas)

# %%
def remove_accents(text: str) -> str:
    return ''.join(
        c for c in unicodedata.normalize('NFKD', text)
        if not unicodedata.combining(c)
    )


def normalize_spacing(text: str) -> str:
    invisible = [
        "\u00A0", "\u2000", "\u2001", "\u2002", "\u2003",
        "\u2004", "\u2005", "\u2006", "\u2007", "\u2008",
        "\u2009", "\u200A", "\u202F", "\u205F", "\u3000",
        "\u200B"     
    ]
    for sp in invisible:
        text = text.replace(sp, " ")

    text = re.sub(r"\s+", " ", text)
    return text.strip()

def normalize_citations(text: str) -> str:
    text = re.sub(r"\bart\.?\s*(\d+)\b", r"art_\1", text)
    text = re.sub(r"§\s*(\d+)", r"par_\1", text)

    roman_map = {
        "i":1, "ii":2, "iii":3, "iv":4, "v":5, "vi":6,
        "vii":7, "viii":8, "ix":9, "x":10, "xi":11, "xii":12
    }

    def roman_to_num(m):
        r = m.group(1).lower()
        return f"inc_{roman_map.get(r, r)}"

    text = re.sub(r"\binciso\s+([ivx]+)\b", roman_to_num, text)
    return text


def general_cleanup(text: str) -> str:

    patterns_remove = [
        r"http\S+",
        r"\S+@\S+",
        r"\(?\d{2}\)?\s?\d{4,5}-?\d{4}",
        r"\b\d{5}-?\d{3}\b",
        r"\b\d{3}\.?\d{3}\.?\d{3}-?\d{2}\b",
        r"\b\d{2}\.?\d{3}\.?\d{3}/?\d{4}-?\d{2}\b",
        r"\b\d{1,2}[\/\-.]\d{1,2}[\/\-.]\d{2,4}\b",
        r"\b\d{1,2}[:h]\d{2}(:\d{2})?\b",
    ]

    for p in patterns_remove:
        text = re.sub(p, " ", text)

    name_pattern = r"\b[A-Z][a-z]+(?:\s+[A-Z][a-z]+)+\b"
    text = re.sub(name_pattern, " ", text)

    return re.sub(r"\s+", " ", text).strip()


def normalize_token(w: str) -> str:
    return w.strip(".,;:!?()[]{}\"'`´“”‘’_-")


def remove_ocr_noise(text: str) -> str:
    clean = []

    for w in text.split():

        w_norm = normalize_token(w)

        if len(w_norm) <= 3:
            continue

        if len(w_norm) == 1:
            continue

        if len(set(w_norm)) <= len(w_norm) // 2:
            continue

        if not any(v in w_norm.lower() for v in "aeiou"):
            continue

        clean.append(w_norm)

    return " ".join(clean)



def preprocess(text: str) -> str:

    if not isinstance(text, str) or not text.strip():
        return ""

    text = normalize_spacing(text)      
    text = general_cleanup(text)
    text = remove_accents(text).lower()
    text = normalize_citations(text)
    text = normalize_spacing(text)     

    words = []
    for w in text.split():
        w_norm = normalize_token(w)

        if w_norm and w_norm not in stop_words and w_norm not in topicos_comuns:
            words.append(w_norm)

    text = " ".join(words)

    text = remove_ocr_noise(text)

    return text.strip()

# %%
doc["clean"] = doc["body"].apply(preprocess)
# Out:
# C:\Users\Maria\AppData\Local\Temp\ipykernel_28564\1964082047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   doc["clean"] = doc["body"].apply(preprocess)

# %%
doc.head()
# Out:
#    themes process_id                        file_name           document_type  \
# 71   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
# 72   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
# 73   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
# 74   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
# 75   [33]  AI_852811  AI_852811_941407_6_19052013.pdf  acordao_de_2_instancia
#
#     pages                                               body  \
# 71      1  {"poder judiciário estado acre gabinete desemb...
# 72      2  {"poder judiciário estado acre gabinete desemb...
# 73      3  {"poder judiciário estado acre gabinete desemb...
# 74      4  {"poder judiciário estado acre gabinete desemb...
# 75      5  {"c f d poder judiciário estado acre gabinete ...
#
#                                                 clean
# 71  declaracao apelacao civel orgao civel banco cr...
# 72  banco cruzeiro representante interpos presente...
# 73  obstante arrazoado recursal dessumo alegada co...
# 74  acolhimento aclaratorios edcl castro meira dec...
# 75  extrato julgamento seguinte unanimidade conhec...

# %%
len(doc)
# Out:
# 142435

# %%
doc['clean'][1466152]
# Out:
# 'ante julgo improcedente extingo resolucao termos artigo_269 honorarios considerando percebe rendimento inferior salarios minimos criterio regiao defiro beneficio assistencia judiciaria gratuita havendo interposicao recebido efeitos oferecimento contrarrazoes decurso respectivo prazo remetam recursal subsecao judiciaria publicada registrada eletronicamente intimem transito julgado arquivem itajai eduardo correia silva substituto titularidade plena assinado eduardo correia silva substituto titularidade plena artigo_1o inc_3 lei_11419 resolucao regiao marco conferencia autenticidade disponivel endereco site preenchimento codigo verificador solicitado codigo adicionais eduardo correia silva'

# %% [markdown]
# ### Bertopic

# %%
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer

# %%
stop_words_list = list(stop_words)

# %%
treino = doc[["clean", "document_type"]]

# %%
treino.head()
# Out:
#                                                 clean           document_type
# 71  declaracao apelacao civel orgao civel banco cr...  acordao_de_2_instancia
# 72  banco cruzeiro representante interpos presente...  acordao_de_2_instancia
# 73  obstante arrazoado recursal dessumo alegada co...  acordao_de_2_instancia
# 74  acolhimento aclaratorios edcl castro meira dec...  acordao_de_2_instancia
# 75  extrato julgamento seguinte unanimidade conhec...  acordao_de_2_instancia

# %%
treino['document_type'].value_counts()
# Out:
# document_type
# peticao_do_RE                       77893
# agravo_em_recurso_extraordinario    34640
# sentenca                            21210
# acordao_de_2_instancia               4740
# despacho_de_admissibilidade          3952
# Name: count, dtype: int64

# %%
docs = list(treino["clean"])

# %%
len(docs)
# Out:
# 142435

# %%
# amostra estratificada
sample_df, _ = train_test_split(
    treino,
    test_size=0.8, 
    stratify=treino["document_type"],
    random_state=42
)
documents = list(sample_df["clean"])

# %%
documents
# Out:
# ['protege particular interesses corretor ajuste verbal restar descumprido dispositivos legais autorizarao corretor promova demanda resguardo direitos unico civil discipline taxativamente comissao devera necessariamente suportada contrato mediacao tornou possivel autorize considerar nula convencao sentido contrario vale citar sentido escolio orlando gomes determinando pagar corretagem prevalecem usos livres todavia contrato mediacao estipulares clausula remuneracao ajuste recorre usos recorrido proferida juizo acabou silenciar venias rogadas suscitadas tendo fundado encontro contidas impor graves prejuizos recorrentes condenadas restituir valores comprovadamente receberam colocaria risco desenvolvimento atividade certo constatar desconhecimento consumidor contratacao profissional corretagem ilegalidade pagamento invalidando negocio juridico firmado recorrida corretora imobiliaria especifica impugnacao trazidos ausente casu condenacao imposta recorrentes inadequada porquanto infringir contratual expresso infringe artigo_5 constituicao verbis ninguem sera deixar alguma senao virtude ninguem sera privado liberdade bens devido legal',
#  'fazenda fazenda nacional regional fazenda nacional regiao cuida assuntos amplamente debatidos inumeras demandas judiciais efeito multiplicador envolvendo fazenda publica trazendo consigo relevantes aspectos economicos politicos sociais juridicos caso inegavel repercussao vista economico materia debatida inumeros processos criar amparo juridico apuracao imposto renda termos artigo_12 lei_7713 reclamatorias trabalhistas entidades previstas referida alegada invocacao principio isonomia tributaria relevancia juridica discussao ressaltada inquestionavel repercussao economica social jogo receita tributaria ingressar cofres publicos representa prejuizo significativo consequencia reflete diretamente execucao politicas sociais discutir efeito multiplicativo supremo milhoes demandas identicas redunda feita consolidada acoes prejuizo erario dimensoes economicas inegavelmente amplas significativas casa bilhoes reais',
#  'advocacia deferimento pretensao deveria considerar disposto paragrafo unico artigo_169 constituicao estabelece artigo_169 despesa pessoal ativo inativo estados distrito municipios podera exceder limites estabelecidos complementar paragrafo unico concessao vantagem aumento remuneracao criacao cargos alteracao estrutura carreiras admissao pessoal titulo orgaos entidades administracao direta indireta fundacoes instituidas mantidas publico poderao feitas previa dotacao orcamentaria suficiente atender projecoes despesa pessoal acrescimos decorrentes artigo_38 disposicoes constitucionais transitorias estabelece artigo_38 promulgacao complementar referida artigo_169 estados distrito municipios poderao despender pessoal sessenta respectivas receitas correntes casu falar irregularidade conduta administracao demandante percebe provento consonancia texto expresso sera adiante exposta evidente impossibilidade juridica visto deferimento pleito deduzido inicial extrapola limites competencia leis venham disciplinar materia relativa concessao aumentos remuneracao servidores publicos iniciativa privativa republica artigo_61 paragrafo alinea propria artigo_64 legislativo competente legislador pena ofensa disciplina legislativo previsto constituicao lembrar devido acatamento principio triparticao poderes estampado artigo_2o carta magna verdadeira clausula petrea confere autonomia legitimidade destinatarios estrita acepcao atribuicoes justificando equidistancia forca especificos modo condicoes interferir atribuicoes historico principio freios contrapesos justificam atuacao legitimamente instituido limites maximiniano figueiredo centro joao pessoa fone',
#  'advogados associados reforma agravada cabimento instrumento artigo_897 artigo_544 recorrente arguiu sede existencia repercussao artigo_543 superior desarmonia dominante supremo natureza vinculo administracao publica incompetencia vice superior denegou seguimento extraordinario interposto recorrente entender recorrida atinente tema repercussao reconhecida consequente consagracao tese juridica semelhante albergada corte superior restando inviabilizado admissibilidade extraordinario reexame seguintes termos extraordinario interposto negou provimento instrumento temas desdobramentos recorrente suscita repercussao apontando violacao dispositivos constitucionais especifica decido recorrido recorrida proferida consonancia corte observa seguintes julgados instrumento revista face publicada vigencia lei_13015 competencia concurso publico contratacao regime celetista corte regional consignou admitido concurso publico contrato regido atrai competencia especializada exame tese recursal sentido servidor publico municipal regido regime juridico administrativo esbarra teor demanda revolvimento nega provimento airr ministro claudio mascarenhas brandao dejt revista pocos caldas competencia contratacao concurso publico regime celetista incompetente exame lide vinculo endereco tomaz tajra joquei clube teresina fone mails email email',
#  'vistos inspecao encaminhem apreciacao juizo admissibilidade recife movimentacao jorge andre carvalho mendonca recursal',
#  'conheco inominado provimento reformar recorrida declarar inexistente debito motivador inclusao orgaos protecao credito condenar reclamada pagamento indenizacao danos morais quantia reais devendo corrigida monetariamente juros mora observancia disposto sumulas honorarios advocaticios termos artigo_55a lei_9099 aracaju marcel maia montalvao voto isabela sampaio alves acompanho marcel maia montalvao termos voto proferido aracaju isabela sampaio alves membro voto camila costa pedrosa ferreira acompanho marcel maia montalvao termos voto proferido aracaju camila costa pedrosa ferreira membro',
#  ...]

# %%
topic_model = BERTopic(min_topic_size=150, embedding_model="paraphrase-multilingual-MiniLM-L12-v2", 
                       language="portuguese")

# %%
topics, probs = topic_model.fit_transform(documents)

# %%
topic_model.visualize_topics()

# %%
topic_model.get_topic_freq()
# Out:
#    Topic  Count
# 0      0  21000
# 2     -1   4378
# 1      1   2046
# 3      2    519
# 4      3    236
# 6      4    156
# 5      5    152

# %%
topic_model.visualize_barchart()

# %%
topic_model.save("bertopic_model")
# Out:
# 2025-11-22 23:44:57,253 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %%
from bertopic import BERTopic

model = BERTopic.load("bertopic_model", embedding_model="paraphrase-multilingual-MiniLM-L12-v2")

# %%
# descobrindo os tópicos presentes na classe "outros"
outros = df_doc[df_doc['document_type'] == "outros"]

# %%
outros.head()
# Out:
#   themes process_id                              file_name document_type  \
# 0  [225]  AI_635072  AI_635072_15320124014_80_13032015.pdf        outros
# 1  [225]  AI_635072  AI_635072_15320124014_80_13032015.pdf        outros
# 2  [225]  AI_635072  AI_635072_288462549_1060_13032015.pdf        outros
# 3  [225]  AI_635072  AI_635072_289561047_1280_15122014.pdf        outros
# 4  [225]  AI_635072  AI_635072_306972753_1280_02062015.pdf        outros
#
#    pages                                               body
# 0      1  {"çft manê ado intimação extraído relação das ...
# 1      2  {"certidão certifico que dirigi nesta capital ...
# 2      1  {"supremo tribunal federal agravo instrumento ...
# 3      1  {"supremo tribunal federal certidão agravo ins...
# 4      1  {"supremo tribunal federal ofício brasília de ...

# %%
len(outros)
# Out:
# 1323841

# %%
# amostra aleatória de documentos "outros"
outros = outros.sample(n=100000, random_state=42)

# %%
outros["clean"] = outros["body"].apply(preprocess)

# %%
outros = outros[["clean", "document_type"]]

# %%
doc_outros = list(outros["clean"])

# %%
topics_outros, probs_outros = model.fit_transform(doc_outros)

# %%
model.get_topic_freq()
# Out:
#     Topic  Count
# 4      -1  48091
# 5       0   3391
# 17      1   2975
# 10      2   2565
# 14      3   2405
# ..    ...    ...
# 65     84    161
# 23     85    159
# 25     86    158
# 89     87    158
# 63     88    154
#
# [90 rows x 2 columns]

# %%
model.visualize_barchart()

# %% [markdown]
# ### LLM + FIRAC com Few Shot Learning

# %%
! pip install langchain openai
# Out:
# Collecting langchain
#   Downloading langchain-1.0.8-py3-none-any.whl.metadata (4.9 kB)
# Collecting openai
#   Downloading openai-2.8.1-py3-none-any.whl.metadata (29 kB)
# Collecting langchain-core<2.0.0,>=1.0.6 (from langchain)
#   Downloading langchain_core-1.1.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Downloading langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from openai) (4.11.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.12.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.6->langchain)
#   Downloading langsmith-0.4.46-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: colorama in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.12.0-cp312-cp312-win_amd64.whl.metadata (1.2 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading orjson-3.11.4-cp312-cp312-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 1.1 MB/s eta 0:00:00
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain)
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maria\downloads\stf-app-clustering-documents\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain) (2.5.0)
# Downloading langchain-1.0.8-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.7 kB ? eta -:--:--
#    ---------------------------------------- 93.7/93.7 kB 2.7 MB/s eta 0:00:00
# Downloading openai-2.8.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    --------------------------------- ------ 0.9/1.0 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 12.8 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.12.0-cp312-cp312-win_amd64.whl (205 kB)
#    ---------------------------------------- 0.0/205.2 kB ? eta -:--:--
#    --------------------------------------- 205.2/205.2 kB 12.2 MB/s eta 0:00:00
# Downloading langchain_core-1.1.0-py3-none-any.whl (473 kB)
#    ---------------------------------------- 0.0/473.8 kB ? eta -:--:--
#    --------------------------------------- 473.8/473.8 kB 30.9 MB/s eta 0:00:00
# Downloading langgraph-1.0.3-py3-none-any.whl (156 kB)
#    ---------------------------------------- 0.0/156.8 kB ? eta -:--:--
#    ---------------------------------------- 156.8/156.8 kB 9.2 MB/s eta 0:00:00
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#    ---------------------------------------- 46.2/46.2 kB 2.4 MB/s eta 0:00:00
# Downloading langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading langsmith-0.4.46-py3-none-any.whl (411 kB)
#    ---------------------------------------- 0.0/411.9 kB ? eta -:--:--
#    --------------------------------------- 411.9/411.9 kB 25.1 MB/s eta 0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.4-cp312-cp312-win_amd64.whl (131 kB)
#    ---------------------------------------- 0.0/131.5 kB ? eta -:--:--
#    ---------------------------------------- 131.5/131.5 kB 8.1 MB/s eta 0:00:00
# Downloading ormsgpack-1.12.0-cp312-cp312-win_amd64.whl (112 kB)
#    ---------------------------------------- 0.0/112.9 kB ? eta -:--:--
#    ---------------------------------------- 112.9/112.9 kB 6.8 MB/s eta 0:00:00
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
#    ---------------------------------------- 0.0/506.3 kB ? eta -:--:--
#    --------------------------------------- 506.3/506.3 kB 16.0 MB/s eta 0:00:00
# Installing collected packages: zstandard, tenacity, ormsgpack, orjson, jsonpointer, jiter, distro, requests-toolbelt, jsonpatch, openai, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
# Successfully installed distro-1.9.0 jiter-0.12.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.0.8 langchain-core-1.1.0 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.2.9 langsmith-0.4.46 openai-2.8.1 orjson-3.11.4 ormsgpack-1.12.0 requests-toolbelt-1.0.0 tenacity-9.1.2 zstandard-0.25.0
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
system_prompt = """Você é um assistente jurídico que gera FIRAC (Facts, Issues, Rules, Analysis, Conclusion)
a partir de textos jurídicos limpos de OCR. Retorne um JSON válido com os campos:
- facts
- issues
- rules
- analysis
- conclusion
Mantenha a linguagem concisa e objetiva. Trate o texto como um único bloco. Não invente informações. 
Caso não haja informação suficiente, retorne campos vazios."""


# few-shot learning
examples = """Exemplo:
Texto: autor ajuizou acao indenizacao contrato descumprido clausula rescisao
Saída esperada:
{
  "facts": [
    {"text":"Autor ajuizou ação de indenização"},
    {"text":"Cláusula de rescisão prevista"}
  ],
  "issues":[{"text":"Se a rescisão contratual foi válida"}],
  "rules":[{"text":"Art. 421 CC","authority":"Código Civil"}],
  "analysis":[{"point":"Aplicando os fatos à lei, a cláusula é válida conforme jurisprudência"}],
  "conclusion":"Pedido de indenização deferido"
}"""

# %%
texto = doc['clean'].iloc[100]

# %%
texto
# Out:
# 'incidir diploma civil conseguinte afasto prejudicial plano verao expurgos inflacionarios plano verao importante diga referencia cita termo inicial apresentou extrato contas constava periodo modo calculos elaborados contador baseados saldos encontrados periodos plano collor collor tendo concordado respectivos valores plano collor plano economico governamental collor anunciado fernando collor mello tentativa estancar fenomeno historico inflacao assolava pais plano previu dentre medidas bloqueio saldos cadernetas poupanca contas correntes aplicacoes overnight plano acarretou expurgos inflacionarios bancos detrimento poupadores tais expurgos base adquirido poupadores ocorreu periodos plano bresser plano verao lacuna legislacao previa alteracao indices promulgacao medida provisoria cadernetas poupanca remuneradas base regra artigo_17 lei_7730 artigo_17 saldos cadernetas poupanca serao atualizados base variacao verificada anterior editada medida provisoria posteriormente convertida lei_8024 determinou conversao saldos cadernetas poupanca cruzeiros limite cinquenta cruzados valores excedentes recolhidos banco central convertidos liberados parcelas mensais iguais sucessivas valores superiores bloqueados repassados bacen ficou estabelecido atualizados fiscal entanto alterou vigente correcao relacao valores continuavam depositados conta poupanca administracao bancos excedentes acao respeito justamente valores mantidos deposito conta poupanca administrada instituicao financeira quantia ultrapassou bloqueadas repassadas bacen rezava artigo_6o saldos cadernetas poupanca serao convertidos cruzeiros proximo credito rendimento paridade estabelecida artigo_1o observado limite cinquenta cruzados quantias excederem limite fixado artigo serao convertidas parcelas mensais iguais sucessivas quantias mencionadas paragrafo anterior serao atualizadas monetariamente variacao fiscal verificada marco conversao acrescida juros equivalentes fracao rata restou evidenciado tratou atualizacao monetaria valores inferiores mantidos bancos depositarios posteriormente notando saldos restassem depositados contas poupanca corrigidos editada alterando redacao artigo_6o dispondo saldos remunerados fiscal artigo_6o saldos cadernetas poupanca serao convertidos cruzeiros proximo credito rendimento caso fazendo sacado atualizacao monetaria variacao fiscal verificada ultimo credito rendimento saque paridade estabelecida artigo_1o observado limite cinquenta cruzados quantias excederem limite fixado artigo serao convertidos cruzeiros parcelas mensais iguais sucessivas todavia congresso nacional desprezou modificacoes converteu lei_8024 redacao original restou revogada conversao perderam eficacia disposicoes circulares banco central nelas embasadas permaneceu correcao poupanca determinava lei_7730 lacuna existente restabelecer redacao convertidas sequer reeditadas perderam eficacia resta cristalino saldos contas poupanca permaneceram bancos deveriam sido'

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("OPENAI_KEY")

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": f"{examples}\n\nTexto novo:\n{texto}"}
]

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# {
#   "facts": [
#     {"text": "Plano Verão e Plano Collor implementados para conter inflação."},
#     {"text": "Medidas incluíram bloqueio e expurgos inflacionários em cadernetas de poupança e contas correntes."},
#     {"text": "Saldos das cadernetas de poupança deveriam ser atualizados com base na variação fiscal e convertidos segundo limites legais."},
#     {"text": "Lei 7.730 e Medida Provisória posteriormente convertida na Lei 8.024 regulavam atualização e conversão dos saldos."},
#     {"text": "Quantias excedentes ao limite de 50 cruzados deveriam ser recolhidas ao Banco Central e liberadas em parcelas mensais."},
#     {"text": "Banco Central estabeleceu regras de atualização monetária e juros equivalentes aos saldos convertidos."},
#     {"text": "Alterações legislativas posteriores modificaram redação do artigo 6º, porém conversões perderam eficácia por revogação e decisões do Congresso."},
#     {"text": "Lacuna legislativa persistiu quanto à correção monetária dos valores mantidos em contas poupança pelos bancos após os expurgos."}
#   ],
#   "issues": [
#     {"text": "Se os saldos das contas poupança depositados e mantidos pelos bancos após os expurgos deveriam ser corrigidos monetariamente."},
#     {"text": "Qual o termo inicial para contagem da atualização e correção dos saldos das cadernetas de poupança."}
#   ],
#   "rules": [
#     {"text": "Artigo 17 da Lei 7.730/1989"},
#     {"text": "Artigo 6º da Medida Provisória convertida na Lei 8.024/1990"},
#     {"text": "Disposições sobre atualização monetária e conversão de saldos em cadernetas de poupança"},
#     {"text": "Princípios gerais de correção monetária e limites legais para bloqueio e liberação das quantias"}
#   ],
#   "analysis": [
#     {"point": "Embora a legislação previa critérios para atualização e bloqueio, alterações e revogações legislativas criaram lacunas."},
#     {"point": "Saldos mantidos pelos bancos, mesmo após os expurgos, deveriam ser atualizados baseando-se na variação fiscal vigente."},
#     {"point": "A falta de reedição das normas de correção e as decisões do Congresso levaram à perda de eficácia da conversão prevista inicialmente."},
#     {"point": "Necessário analisar se há direito dos poupadores à correção dos valores remanescentes em suas contas após o Plano Verão."}
#   ],
#   "conclusion": ""
# }
